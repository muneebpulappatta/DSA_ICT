# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("G:\study\Data Science - ICT\Week 7\Add_sales_data_2018.csv")

# %%
data.head()
# Out:
#          Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0  2018-10-08              208.00              222.25              206.85
# 1  2018-10-05              217.00              218.60              205.90
# 2  2018-10-04              223.50              227.80              216.15
# 3  2018-10-03              230.00              237.50              225.75
# 4  2018-10-01              234.55              234.60              221.05
#
#    Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# 0              216.00              215.15              4093.065
# 1              210.25              209.20              4042.448
# 2              217.25              218.20              4213.819
# 3              226.45              227.60              4391.665
# 4              230.30              230.90              4350.683

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  205 non-null    object
#  1   Add1(in Thousands)    205 non-null    float64
#  2   Add2(in Thousands)    205 non-null    float64
#  3   Add3(in Thousands)    205 non-null    float64
#  4   Add4(in Thousands)    205 non-null    float64
#  5   Add5(in Thousands)    205 non-null    float64
#  6   Profit(in Thousands)  205 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 11.3+ KB

# %% [markdown]
# # 1. First of all, check whether there is any relationship between the amount spent for advertising through five different companies and profit generated.

# %%
freqgraph=data.select_dtypes(include=['float'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
corr_matrix = data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corr_matrix,vmin=0.97,vmax=1,annot=True,linewidth=0.2)
# Out:
# <AxesSubplot:>

# %%
##There is strong positve correlation between the amount spent for advertising in all five different companies and profit generated as all the correlations occupies between 0.97 and 1.

# %% [markdown]
# # 2. Build a regression model to predict the profit from the given data and comment your findings on it.

# %%
y= data['Profit(in Thousands)']

# %%
X= data.drop(['Date','Profit(in Thousands)'],axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Add1(in Thousands)  205 non-null    float64
#  1   Add2(in Thousands)  205 non-null    float64
#  2   Add3(in Thousands)  205 non-null    float64
#  3   Add4(in Thousands)  205 non-null    float64
#  4   Add5(in Thousands)  205 non-null    float64
# dtypes: float64(5)
# memory usage: 8.1 KB

# %%
X
# Out:
#      Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0                208.00              222.25              206.85
# 1                217.00              218.60              205.90
# 2                223.50              227.80              216.15
# 3                230.00              237.50              225.75
# 4                234.55              234.60              221.05
# ..                  ...                 ...                 ...
# 200              288.00              288.25              279.20
# 201              290.00              292.50              282.20
# 202              298.60              298.60              286.65
# 203              290.00              299.55              285.90
# 204              287.55              289.90              285.05
#
#      Add4(in Thousands)  Add5(in Thousands)
# 0                216.00              215.15
# 1                210.25              209.20
# 2                217.25              218.20
# 3                226.45              227.60
# 4                230.30              230.90
# ..                  ...                 ...
# 200              284.50              284.30
# 201              284.80              284.45
# 202              287.45              287.80
# 203              297.85              298.35
# 204              288.05              288.45
#
# [205 rows x 5 columns]

# %%
y
# Out:
# 0      4093.065
# 1      4042.448
# 2      4213.819
# 3      4391.665
# 4      4350.683
#          ...
# 200    5374.105
# 201    5439.655
# 202    5545.013
# 203    5565.444
# 204    5421.842
# Name: Profit(in Thousands), Length: 205, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=.25)

# %%
##building linear regression model
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
##creating model using training data
model = lr.fit(X_train,y_train)

# %%
print(X_test)
# Out:
#      Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 15               216.35              223.70              212.65
# 9                233.55              239.20              230.75
# 100              280.00              281.35              251.85
# 132              258.05              263.50              253.70
# 68               265.10              268.40              261.20
# 95               244.10              248.35              240.55
# 159              287.95              289.00              280.90
# 162              282.00              286.50              276.10
# 147              274.80              276.95              270.55
# 182              315.00              319.10              312.55
# 191              306.50              309.30              303.55
# 164              259.00              270.30              253.25
# 65               271.00              273.10              263.25
# 175              306.00              310.00              300.95
# 73               263.70              264.75              257.00
# 152              264.20              271.90              263.00
# 18               221.00              224.50              219.10
# 82               266.90              269.70              263.30
# 86               269.70              269.70              258.55
# 143              275.90              275.90              266.60
# 60               268.25              276.20              267.00
# 101              284.40              290.50              284.40
# 98               240.00              245.60              237.25
# 30               246.90              246.90              239.25
# 25               233.85              237.70              232.70
# 16               222.50              225.40              214.85
# 168              302.90              303.70              286.10
# 195              302.25              303.00              298.15
# 97               243.50              249.30              242.50
# 194              301.00              306.35              299.70
# 67               263.00              268.25              261.45
# 120              274.00              277.35              271.75
# 154              265.00              268.85              262.20
# 202              298.60              298.60              286.65
# 79               262.75              268.40              262.75
# 69               264.80              269.70              263.30
# 145              272.00              274.45              265.15
# 55               257.90              257.90              242.10
# 45               243.70              247.00              240.90
# 84               255.50              264.70              254.80
# 146              276.70              283.10              271.45
# 66               262.70              270.15              262.70
# 111              292.50              293.65              288.75
# 153              265.95              269.90              261.10
# 96               248.30              248.95              243.35
# 38               237.25              240.50              235.05
# 24               235.35              237.30              232.10
# 139              278.00              284.40              277.25
# 112              283.05              291.25              282.05
# 29               240.30              240.60              233.10
# 19               224.00              225.00              218.20
# 178              323.00              326.90              311.45
#
#      Add4(in Thousands)  Add5(in Thousands)
# 15               221.65              222.65
# 9                234.00              233.30
# 100              257.00              255.90
# 132              263.45              262.20
# 68               263.15              265.60
# 95               244.00              243.55
# 159              281.50              281.95
# 162              280.40              280.45
# 147              276.60              275.65
# 182              314.25              314.10
# 191              306.80              306.60
# 164              266.00              266.70
# 65               264.50              264.45
# 175              309.90              308.35
# 73               260.55              260.85
# 152              271.20              270.70
# 18               223.15              222.95
# 82               267.00              267.10
# 86               265.10              263.25
# 143              268.50              268.35
# 60               275.30              275.25
# 101              287.00              287.50
# 98               241.40              241.10
# 30               240.90              240.55
# 25               234.20              234.55
# 16               216.35              216.00
# 168              291.15              290.65
# 195              300.20              300.15
# 97               247.50              247.50
# 194              302.80              302.75
# 67               265.05              263.95
# 120              275.70              275.50
# 154              266.50              266.60
# 202              287.45              287.80
# 79               267.20              267.60
# 69               264.60              267.35
# 145              268.90              268.90
# 55               243.90              243.25
# 45               243.65              242.20
# 84               264.20              263.75
# 146              272.50              274.15
# 66               269.20              269.35
# 111              291.20              291.20
# 153              262.90              262.15
# 96               245.10              244.70
# 38               236.35              236.35
# 24               237.30              236.00
# 139              279.55              279.60
# 112              289.10              289.10
# 29               235.50              235.45
# 19               220.95              221.05
# 178              317.60              316.40

# %%
predictions = model.predict(X_test)

# %%
print(y_test)
# Out:
# 15     4152.066
# 9      4446.441
# 100    5131.898
# 132    4907.560
# 68     5004.282
# 95     4623.793
# 159    5384.175
# 162    5328.025
# 147    5175.051
# 182    5956.323
# 191    5780.799
# 164    4997.719
# 65     5075.858
# 175    5784.540
# 73     4936.120
# 152    5065.652
# 18     4190.965
# 82     5034.726
# 86     5015.536
# 143    5134.657
# 60     5145.131
# 101    5421.940
# 98     4569.293
# 30     4598.292
# 25     4436.321
# 16     4175.677
# 168    5616.791
# 195    5667.250
# 97     4648.834
# 194    5717.838
# 67     5001.615
# 120    5182.368
# 154    5017.503
# 202    5545.013
# 79     5013.207
# 69     5030.451
# 145    5108.626
# 55     4760.877
# 45     4606.340
# 84     4925.861
# 146    5250.788
# 66     5038.222
# 111    5491.792
# 153    5019.997
# 96     4647.356
# 38     4486.380
# 24     4435.174
# 139    5300.437
# 112    5425.190
# 29     4482.183
# 19     4193.095
# 178    6062.457
# Name: Profit(in Thousands), dtype: float64

# %%
print(predictions)
# Out:
# [4152.066 4446.441 5131.898 4907.56  5004.282 4623.793 5384.175 5328.025
#  5175.051 5956.323 5780.799 4997.719 5075.858 5784.54  4936.12  5065.652
#  4190.965 5034.726 5015.536 5134.657 5145.131 5421.94  4569.293 4598.292
#  4436.321 4175.677 5616.791 5667.25  4648.834 5717.838 5001.615 5182.368
#  5017.503 5545.013 5013.207 5030.451 5108.626 4760.877 4606.34  4925.861
#  5250.788 5038.222 5491.792 5019.997 4647.356 4486.38  4435.174 5300.437
#  5425.19  4482.183 4193.095 6062.457]

# %%
from sklearn.metrics import mean_squared_error

# %%
print('MSE is', mean_squared_error(y_test,predictions))
# Out:
# MSE is 3.8177566733216664e-25

# %%
from sklearn.metrics import r2_score
print('R Sqrd Value is : ',r2_score(y_test,predictions))
# Out:
# R Sqrd Value is :  1.0

# %%
model.coef_
# Out:
# array([ 1.  , 12.38,  3.5 ,  1.  ,  0.9 ])

# %%
model.intercept_
# Out:
# 1.8189894035458565e-12

# %%
#as R Squared Value = 1 and MSE is 3.82, the prediction is perfect fit for the test values.

# %% [markdown]
# # 3. Predict the profit generated by the company, if they wish to spend the following amount for advertisement.
# ## Add1(in Thousands) 290
# ## Add2(in Thousands) 312
# ## Add3(in Thousands) 309
# ## Add4(in Thousands) 298
# ## Add5(in Thousands) 320

# %%
prediction1 = model.predict([[290,312,309,298,320]])
print(prediction1)
# Out:
# [5820.06]

# %%
#Let's check the answer by calculation 
290*1+312*12.38+309*3.5+298*1+320*0.9+1.8189894035458565e-12
# Out:
# 5820.060000000002

# %%
#multilply by thousand as profit is given in thousands
5820.060000000002*1000
# Out:
# 5820060.000000002

# %%
##The profit generated by the company, if they wish to spend the amounts 290,312,309,298,320 for the advertisement is 5820060 Rupees.
